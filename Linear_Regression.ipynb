# %%
#Import pandas library

import pandas as pd

# %%
#Read the dataset from csv file

data_all = pd.read_csv('Boston.csv')

# %%
# Have a glance at the shape
# Print first five rows of the data

data_all.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# **This data frame contains following columns:**
#
# **Crim:** Per capita crime rate by town
#
# **Zn:** Proportion of residential land zoned for lots over 25,000 sq. ft.
#
# **Indus:** Proportion of non-retail business acres per town
#
# **Chas:** Charles River dummy variable (= 1 if tract bounds river; 0, otherwise)
#
# **Nox:** Nitrogen oxides concentration (parts per 10 million)
#
# **Rm:** Average number of rooms per dwelling
#
# **Age:** Proportion of owner-occupied units built before 1940
#
# **Dis:** Weighted mean of distances to five Boston employment centers
#
# **Rad:** Index of accessibility to radial highways
#
# **Tax:** Full-value property tax rate per $10,000
#
# **Ptratio:** Pupil–Teacher ratio by town
#
# **Black:** 1000(Bk – 0.63) ^2, where Bk is the proportion of Blacks by town
#
# **Lstat:** Lower status of the population (percent)
#
# **Medv:** Median value of owner-occupied homes in $1000s

# %%
# Have a glance at the dependent and independent variables

indep_depen = data_all.loc[:,['lstat', 'medv']]

indep_depen.head()
# Out:
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
# Visualize the change in the variables

import matplotlib.pyplot as plt

# Plot accessor
data_all.plot(x='lstat', y='medv', style='o')

plt.xlabel('lstat')
plt.ylabel('medv')

# Display all open figures
plt.show()

# %%
# # Divide the data into independent and dependent variables

# # Independet 
# X_features = pd.DataFrame(data_all['lstat'])

# # Dependent 
# y_labels = pd.DataFrame(data_all['medv'])

# %%
# Divide the data into independent and dependent variables

# Independet 
X_features = data_all.loc[:,'lstat'].values.reshape(-1, 1) # values converts it into a numpy array

# Dependent 
y_labels = data_all.loc[:,'medv'].values.reshape(-1, 1) # -1 means that calculate the dimension of rows, but have 1 column

# %%
# Split the data into train and test sets

from sklearn.model_selection import train_test_split

# 60% for training set, 40% for test set 
X_train, X_test, y_train, y_test = train_test_split(X_features, y_labels, test_size= 0.4, random_state=1)


# Data for test set will be divided into two. 20% for test set and 20% for validation set
# X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=1)


# To print out the all data percentage. 
data = [y_train, y_test]
data_labels = ["Train: ", "Test: "]


for (data_label, dataset) in zip(data_labels,data):

    print ( (data_label) , round(len(dataset)/len(y_labels), 2))
# Out:
# Train:  0.6
# Test:  0.4

# %%
# Shape of the train,  test and validation sets

print()
print ("X_train:", X_train.shape)
print ("y_train:", y_train.shape)
print ("X_test:", X_test.shape)
print ("y_test:", y_test.shape)
# print ("X_val:", X_val.shape)
# print ("y_val:", y_val.shape)
# Out:
# X_train: (303, 1)
# y_train: (303, 1)
# X_test: (203, 1)
# y_test: (203, 1)

# %%
# Train the algorithm

from sklearn.linear_model import LinearRegression

linear_regressor = LinearRegression()  # # create object for the class

linear_regressor.fit(X_train, y_train) # perform linear regression

# X_train.head(10)
# Out:
# LinearRegression()

# %%
# Out:
# array([[28.3891185]])

# %%
# Retrieve the intercept

print ('Intercept: ', linear_regressor.intercept_)
# Out:
# Intercept:  [34.13076276]

# %%
# Retrieve the slope

print ('Coefficient: ', linear_regressor.coef_)
# Out:
# Coefficient:  [[-0.91573274]]

# %%
print(linear_regressor.score(X_train,y_train))
# Out:
# 0.5743938467472869

# %%
# Input needs to be two dimensional (reshape makes input two dimensional )
# make one prediction
linear_regressor.predict(X_test[0].reshape(-1,1))
# Out:
# array([[27.23529525]])

# %%
# Predicted value

y_pred = linear_regressor.predict(X_test)

y_pred
# Out:
# array([[27.23529525],
#        [27.55580171],
#        [16.91498731],
#        [26.71332759],
#        [24.79944617],
#        [23.94781473],
#        [29.8268189 ],
#        [22.18960787],
#        [17.72083211],
#        [26.06315735],
#        [27.04299138],
#        [29.90923484],
#        [21.66764021],
#        [24.75365953],
#        [23.39837508],
#        [23.02292466],
#        [12.84913395],
#        [29.89092019],
#        [27.32686852],
#        [ 7.08917504],
#        [23.59983629],
#        [18.88381269],
#        [25.63276296],
#        [28.52647841],
#        [29.85429088],
#        [11.79604131],
#        [15.50475889],
#        [24.48809704],
#        [27.48254309],
#        [15.0377352 ],
#        [29.10339003],
#        [17.22633644],
#        [31.49345248],
#        [19.07611657],
#        [25.80675218],
#        [21.68595487],
#        [17.83987737],
#        [29.24990727],
#        [12.75756068],
#        [20.41308636],
#        [27.40928447],
# ...

# %%
y_test
# Out:
# array([[28.2],
#        [23.9],
#        [16.6],
#        [22. ],
#        [20.8],
#        [23. ],
#        [27.9],
#        [14.5],
#        [21.5],
#        [22.6],
#        [23.7],
#        [31.2],
#        [19.3],
#        [19.4],
#        [19.4],
#        [27.9],
#        [13.9],
#        [50. ],
#        [24.1],
#        [14.6],
#        [16.2],
#        [15.6],
#        [23.8],
#        [25. ],
#        [23.5],
#        [ 8.3],
#        [13.5],
#        [17.5],
#        [43.1],
#        [11.5],
#        [24.1],
#        [18.5],
#        [50. ],
#        [12.6],
#        [19.8],
#        [24.5],
#        [14.9],
#        [36.2],
#        [11.9],
#        [19.1],
#        [22.6],
#        [20.7],
#        [30.1],
#        [13.3],
#        [14.6],
#        [ 8.4],
#        [50. ],
#        [12.7],
#        [25. ],
#        [18.6],
#        [29.8],
#        [22.2],
#        [28.7],
#        [23.8],
#        [ 8.1],
#        [22.2],
#        [ 6.3],
#        [22.1],
# ...

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color='yellow')
plt.xlabel("Hiegth in cm")
plt.ylabel("Weight in lbs")
plt.show()

# %%
# Evaluate algorithm

from sklearn import metrics
import numpy as np

print ('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
print ('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
print ('Root Mean Squared Error: ', np.sqrt(metrics.mean_absolute_error(y_test, y_pred)))
# Out:
# Mean Absolute Error:  4.85248058295052
# Mean Squared Error:  45.231880629772576
# Root Mean Squared Error:  2.202834669908416
