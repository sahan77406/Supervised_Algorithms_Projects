# %% [markdown]
# #### Hyperparameter Tuning Using Grid Search and Random Search in Python

# %% [markdown]
# #### Grid Search

# %% [markdown]
# Define a parameter space or parameter grid, where we include a set of possible hyperparameter values that can be used to build the model.
#
# Grid search looks at every possible combination of hyperparameters to find the best model
#
# The grid search is used to place these hyperparameters in a matrix-like structure, and the model is trained on every combination of hyperparameter values.
#
# The model with the best performance is then selected.

# %% [markdown]
# #### Random Search

# %% [markdown]
# Random search only selects and tests a random combination of hyperparameters.
#
# Random search randomly samples from a grid of hyperparameters.
#
# The number of total runs can be specified before returning the best model.

# %%
import pandas as pd
import joblib
from sklearn.exceptions import ConvergenceWarning
from sklearn.exceptions import DataConversionWarning
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=ConvergenceWarning)
warnings.filterwarnings('ignore', category=DataConversionWarning)

data_df = pd.read_csv('wine_quality.csv')
# data_df.head()
data_df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
data_df.describe()
# Out:
#               type  fixed acidity  volatile acidity  citric acid  \
# count  6497.000000    6497.000000       6497.000000  6497.000000
# mean      0.246114       7.216579          0.339691     0.318722
# std       0.430779       1.295751          0.164548     0.145231
# min       0.000000       3.800000          0.080000     0.000000
# 25%       0.000000       6.400000          0.230000     0.250000
# 50%       0.000000       7.000000          0.290000     0.310000
# 75%       0.000000       7.700000          0.400000     0.390000
# max       1.000000      15.900000          1.580000     1.660000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     6497.000000  6497.000000          6497.000000           6497.000000
# mean         5.444326     0.056042            30.525319            115.744574
# std          4.757392     0.035031            17.749400             56.521855
# min          0.600000     0.009000             1.000000              6.000000
# 25%          1.800000     0.038000            17.000000             77.000000
# 50%          3.000000     0.047000            29.000000            118.000000
# 75%          8.100000     0.065000            41.000000            156.000000
# max         65.800000     0.611000           289.000000            440.000000
#
#            density           pH    sulphates      alcohol      quality  \
# count  6497.000000  6497.000000  6497.000000  6497.000000  6497.000000
# mean      0.994697     3.218395     0.531215    10.491801     5.818378
# std       0.002999     0.160637     0.148768     1.192712     0.873255
# min       0.987110     2.720000     0.220000     8.000000     3.000000
# 25%       0.992340     3.110000     0.430000     9.500000     5.000000
# 50%       0.994890     3.210000     0.510000    10.300000     6.000000
# 75%       0.996990     3.320000     0.600000    11.300000     6.000000
# max       1.038980     4.010000     2.000000    14.900000     9.000000
#
#        target_quality
# count     6497.000000
# mean         0.633061
# std          0.482007
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# #### Converting type to numeric

# %%
import numpy as np
# Creating type dictionary
# Replacing type data with numerical data by using type dictionary

# type = {'white' : 0, 'red' :1}
# data_df['type'] = data_df['type'].map(type)
# data_df.head(10)

data_df['type'] = np.where(data_df['type'] == 'white', 0, 1)

data_df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6492     1            6.2             0.600         0.08             2.0
# 6493     1            5.9             0.550         0.10             2.2
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %% [markdown]
# #### Checking missing data

# %%
data_df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [markdown]
# #### Replacing missing data with the mean of the existing data

# %%
# fixed acidity
data_df['fixed acidity'].fillna(data_df['fixed acidity'].mean(), inplace=True)

# volatile acidity
data_df['volatile acidity'].fillna(data_df['volatile acidity'].mean(), inplace=True)

# citric acid
data_df['citric acid'].fillna(data_df['citric acid'].mean(), inplace=True)

# residual sugar
data_df['residual sugar'].fillna(data_df['residual sugar'].mean(), inplace=True)

# chlorides
data_df['chlorides'].fillna(data_df['chlorides'].mean(), inplace=True)

# pH
data_df['pH'].fillna(data_df['pH'].mean(), inplace=True)

# sulphates
data_df['sulphates'].fillna(data_df['sulphates'].mean(), inplace=True)



data_df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6492     1            6.2             0.600         0.08             2.0
# 6493     1            5.9             0.550         0.10             2.2
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0      0.450000      8.8        6
# 1      0.490000      9.5        6
# 2      0.440000     10.1        6
# 3      0.400000      9.9        6
# 4      0.400000      9.9        6
# ...         ...      ...      ...
# 6492   0.580000     10.5        5
# 6493   0.531215     11.2        6
# 6494   0.750000     11.0        6
# 6495   0.710000     10.2        5
# 6496   0.660000     11.0        6
#
# [6497 rows x 13 columns]

# %% [markdown]
# #### Turn this into a binary classification task
#
# Assigning a value of 0 to all data points with a quality value of less than or equal to 5,
#
# And a value of 1 to a quality value of more than 5
#
# If value <= 5, quality == 0
#
# if value > 5, quality == 1

# %%
import numpy as np

# where(condition, [x, y])
# Return elements chosen from x or y depending on condition

data_df['target_quality'] = np.where(data_df['quality']>5, 1, 0)

# %% [markdown]
# Split the dependent (target, label) and independent (feature) variables in this dataframe:

# %%
# Drop specified labels from rows or columns.
# Remove rows or columns by specifying label names and corresponding axis, or by specifying directly index or column names.
# When using a multi-index, labels on different levels can be removed by specifying the level. 

# axis 0 represents rows and axis 1 represents columns

data_df2 = data_df.drop(['quality'],axis=1)
x_feature = data_df2.drop(['target_quality'],axis=1)
y_label = data_df2[['target_quality']]

# %% [markdown]
# #### Building the Model
#
# Instantiating a random forest classifier
#
# Tuning the hyperparameters of this model to create the best algorithm for the dataset

# %%
from sklearn.ensemble import RandomForestClassifier

# A random forest classifier.
# A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset
# and uses averaging to improve the predictive accuracy and control over-fitting.
# The sub-sample size is controlled with the max_samples parameter if bootstrap=True (default), otherwise the whole dataset is used to build each tree.

rf = RandomForestClassifier()

# %% [markdown]
# #### Grid Search

# %% [markdown]
# #### Defining the Hyperparameter Space
#
# “Max_depth”: It represents the maximum level of each tree in the random forest model.
#
# “Max_features”: The maximum number of features that the random forest model is allowed to try at each split.
#
# “N_estimators”: The number of decision trees in the forest.
#
# “Min_samples_leaf”: The minimum number of samples required to be at the leaf node of each tree.
#
# “Min_samples_split”: The minimum number of samples required to split an internal node of each tree.

# %%
grid_space={'max_depth':[3,5,10,None],
              'n_estimators':[10,100,200],
            #   'max_features':[1,3,5,7],
            #   'min_samples_leaf':[1,2,3],
            #   'min_samples_split':[1,2,3]
           }

# %% [markdown]
# #### Hyperparameter tuning

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
from sklearn.model_selection import GridSearchCV

cv_grid = GridSearchCV(rf,param_grid=grid_space,cv=3,scoring='accuracy')

cv_grid.fit(x_feature, y_label.values.ravel())

print_results(cv_grid)
# Out:
# BEST PARAMS: {'max_depth': 3, 'n_estimators': 100}
#
# 0.706 (+/-0.031) for {'max_depth': 3, 'n_estimators': 10}
# 0.706 (+/-0.042) for {'max_depth': 3, 'n_estimators': 100}
# 0.702 (+/-0.044) for {'max_depth': 3, 'n_estimators': 200}
# 0.695 (+/-0.054) for {'max_depth': 5, 'n_estimators': 10}
# 0.693 (+/-0.04) for {'max_depth': 5, 'n_estimators': 100}
# 0.705 (+/-0.041) for {'max_depth': 5, 'n_estimators': 200}
# 0.681 (+/-0.085) for {'max_depth': 10, 'n_estimators': 10}
# 0.7 (+/-0.088) for {'max_depth': 10, 'n_estimators': 100}
# 0.697 (+/-0.099) for {'max_depth': 10, 'n_estimators': 200}
# 0.686 (+/-0.087) for {'max_depth': None, 'n_estimators': 10}
# 0.705 (+/-0.082) for {'max_depth': None, 'n_estimators': 100}
# 0.701 (+/-0.096) for {'max_depth': None, 'n_estimators': 200}

# %%
cv_grid.best_estimator_
# Out:
# RandomForestClassifier(max_depth=3)

# %%
joblib.dump(cv_grid.best_estimator_, 'GS_model.pkl')
# Out:
# ['GS_model.pkl']

# %% [markdown]
# #### Random Search

# %% [markdown]
# #### Defining the Hyperparameter Space

# %%
from scipy.stats import randint

rs_space={'max_depth':list(np.arange(10, 100, step=10)) + [None],
              'n_estimators':np.arange(10, 500, step=50),
            #   'max_features':randint(1,7),
            #   'criterion':['gini','entropy'],
            #   'min_samples_leaf':randint(1,4),
            #   'min_samples_split':np.arange(2, 10, step=2)
         }

# %%
from sklearn.model_selection import RandomizedSearchCV

rf = RandomForestClassifier()
cv_random = RandomizedSearchCV(rf, rs_space, n_iter=100, scoring='accuracy', n_jobs=-1, cv=3)

cv_random.fit(x_feature, y_label.values.ravel())

print_results(cv_random)
# Out:
# BEST PARAMS: {'n_estimators': 60, 'max_depth': 10}
#
# 0.674 (+/-0.101) for {'n_estimators': 10, 'max_depth': 10}
# 0.716 (+/-0.046) for {'n_estimators': 60, 'max_depth': 10}
# 0.7 (+/-0.081) for {'n_estimators': 110, 'max_depth': 10}
# 0.703 (+/-0.075) for {'n_estimators': 160, 'max_depth': 10}
# 0.7 (+/-0.091) for {'n_estimators': 210, 'max_depth': 10}
# 0.692 (+/-0.096) for {'n_estimators': 260, 'max_depth': 10}
# 0.704 (+/-0.087) for {'n_estimators': 310, 'max_depth': 10}
# 0.702 (+/-0.074) for {'n_estimators': 360, 'max_depth': 10}
# 0.701 (+/-0.083) for {'n_estimators': 410, 'max_depth': 10}
# 0.696 (+/-0.088) for {'n_estimators': 460, 'max_depth': 10}
# 0.666 (+/-0.127) for {'n_estimators': 10, 'max_depth': 20}
# 0.7 (+/-0.072) for {'n_estimators': 60, 'max_depth': 20}
# 0.701 (+/-0.078) for {'n_estimators': 110, 'max_depth': 20}
# 0.699 (+/-0.093) for {'n_estimators': 160, 'max_depth': 20}
# 0.698 (+/-0.096) for {'n_estimators': 210, 'max_depth': 20}
# 0.697 (+/-0.103) for {'n_estimators': 260, 'max_depth': 20}
# 0.692 (+/-0.1) for {'n_estimators': 310, 'max_depth': 20}
# 0.696 (+/-0.108) for {'n_estimators': 360, 'max_depth': 20}
# 0.692 (+/-0.115) for {'n_estimators': 410, 'max_depth': 20}
# 0.696 (+/-0.098) for {'n_estimators': 460, 'max_depth': 20}
# 0.678 (+/-0.079) for {'n_estimators': 10, 'max_depth': 30}
# 0.7 (+/-0.087) for {'n_estimators': 60, 'max_depth': 30}
# 0.701 (+/-0.081) for {'n_estimators': 110, 'max_depth': 30}
# 0.698 (+/-0.102) for {'n_estimators': 160, 'max_depth': 30}
# 0.696 (+/-0.107) for {'n_estimators': 210, 'max_depth': 30}
# 0.701 (+/-0.089) for {'n_estimators': 260, 'max_depth': 30}
# 0.695 (+/-0.106) for {'n_estimators': 310, 'max_depth': 30}
# 0.695 (+/-0.103) for {'n_estimators': 360, 'max_depth': 30}
# 0.695 (+/-0.104) for {'n_estimators': 410, 'max_depth': 30}
# 0.693 (+/-0.103) for {'n_estimators': 460, 'max_depth': 30}
# 0.677 (+/-0.104) for {'n_estimators': 10, 'max_depth': 40}
# 0.7 (+/-0.087) for {'n_estimators': 60, 'max_depth': 40}
# 0.703 (+/-0.087) for {'n_estimators': 110, 'max_depth': 40}
# 0.696 (+/-0.095) for {'n_estimators': 160, 'max_depth': 40}
# 0.709 (+/-0.074) for {'n_estimators': 210, 'max_depth': 40}
# 0.699 (+/-0.102) for {'n_estimators': 260, 'max_depth': 40}
# 0.691 (+/-0.11) for {'n_estimators': 310, 'max_depth': 40}
# 0.696 (+/-0.103) for {'n_estimators': 360, 'max_depth': 40}
# 0.698 (+/-0.1) for {'n_estimators': 410, 'max_depth': 40}
# 0.697 (+/-0.102) for {'n_estimators': 460, 'max_depth': 40}
# 0.662 (+/-0.13) for {'n_estimators': 10, 'max_depth': 50}
# 0.688 (+/-0.12) for {'n_estimators': 60, 'max_depth': 50}
# 0.69 (+/-0.112) for {'n_estimators': 110, 'max_depth': 50}
# 0.693 (+/-0.098) for {'n_estimators': 160, 'max_depth': 50}
# 0.697 (+/-0.106) for {'n_estimators': 210, 'max_depth': 50}
# 0.7 (+/-0.086) for {'n_estimators': 260, 'max_depth': 50}
# 0.691 (+/-0.111) for {'n_estimators': 310, 'max_depth': 50}
# 0.699 (+/-0.088) for {'n_estimators': 360, 'max_depth': 50}
# 0.693 (+/-0.112) for {'n_estimators': 410, 'max_depth': 50}
# 0.696 (+/-0.099) for {'n_estimators': 460, 'max_depth': 50}
# 0.68 (+/-0.087) for {'n_estimators': 10, 'max_depth': 60}
# 0.686 (+/-0.114) for {'n_estimators': 60, 'max_depth': 60}
# 0.703 (+/-0.083) for {'n_estimators': 110, 'max_depth': 60}
# 0.697 (+/-0.104) for {'n_estimators': 160, 'max_depth': 60}
# 0.691 (+/-0.11) for {'n_estimators': 210, 'max_depth': 60}
# 0.7 (+/-0.097) for {'n_estimators': 260, 'max_depth': 60}
# 0.705 (+/-0.074) for {'n_estimators': 310, 'max_depth': 60}
# 0.706 (+/-0.067) for {'n_estimators': 360, 'max_depth': 60}
# 0.697 (+/-0.098) for {'n_estimators': 410, 'max_depth': 60}
# 0.7 (+/-0.112) for {'n_estimators': 460, 'max_depth': 60}
# 0.684 (+/-0.095) for {'n_estimators': 10, 'max_depth': 70}
# 0.693 (+/-0.105) for {'n_estimators': 60, 'max_depth': 70}
# 0.689 (+/-0.117) for {'n_estimators': 110, 'max_depth': 70}
# 0.702 (+/-0.097) for {'n_estimators': 160, 'max_depth': 70}
# 0.692 (+/-0.109) for {'n_estimators': 210, 'max_depth': 70}
# 0.7 (+/-0.095) for {'n_estimators': 260, 'max_depth': 70}
# 0.704 (+/-0.085) for {'n_estimators': 310, 'max_depth': 70}
# 0.693 (+/-0.106) for {'n_estimators': 360, 'max_depth': 70}
# 0.696 (+/-0.097) for {'n_estimators': 410, 'max_depth': 70}
# 0.694 (+/-0.105) for {'n_estimators': 460, 'max_depth': 70}
# 0.689 (+/-0.071) for {'n_estimators': 10, 'max_depth': 80}
# 0.682 (+/-0.125) for {'n_estimators': 60, 'max_depth': 80}
# 0.689 (+/-0.118) for {'n_estimators': 110, 'max_depth': 80}
# 0.699 (+/-0.104) for {'n_estimators': 160, 'max_depth': 80}
# 0.697 (+/-0.107) for {'n_estimators': 210, 'max_depth': 80}
# 0.69 (+/-0.111) for {'n_estimators': 260, 'max_depth': 80}
# 0.707 (+/-0.073) for {'n_estimators': 310, 'max_depth': 80}
# 0.699 (+/-0.099) for {'n_estimators': 360, 'max_depth': 80}
# 0.694 (+/-0.103) for {'n_estimators': 410, 'max_depth': 80}
# 0.696 (+/-0.101) for {'n_estimators': 460, 'max_depth': 80}
# 0.667 (+/-0.123) for {'n_estimators': 10, 'max_depth': 90}
# 0.691 (+/-0.102) for {'n_estimators': 60, 'max_depth': 90}
# 0.694 (+/-0.09) for {'n_estimators': 110, 'max_depth': 90}
# 0.701 (+/-0.086) for {'n_estimators': 160, 'max_depth': 90}
# 0.694 (+/-0.105) for {'n_estimators': 210, 'max_depth': 90}
# 0.709 (+/-0.078) for {'n_estimators': 260, 'max_depth': 90}
# 0.696 (+/-0.106) for {'n_estimators': 310, 'max_depth': 90}
# 0.694 (+/-0.098) for {'n_estimators': 360, 'max_depth': 90}
# 0.694 (+/-0.107) for {'n_estimators': 410, 'max_depth': 90}
# 0.699 (+/-0.095) for {'n_estimators': 460, 'max_depth': 90}
# 0.685 (+/-0.096) for {'n_estimators': 10, 'max_depth': None}
# 0.705 (+/-0.073) for {'n_estimators': 60, 'max_depth': None}
# 0.696 (+/-0.096) for {'n_estimators': 110, 'max_depth': None}
# 0.705 (+/-0.097) for {'n_estimators': 160, 'max_depth': None}
# 0.702 (+/-0.082) for {'n_estimators': 210, 'max_depth': None}
# 0.699 (+/-0.087) for {'n_estimators': 260, 'max_depth': None}
# 0.705 (+/-0.073) for {'n_estimators': 310, 'max_depth': None}
# 0.695 (+/-0.104) for {'n_estimators': 360, 'max_depth': None}
# 0.694 (+/-0.111) for {'n_estimators': 410, 'max_depth': None}
# 0.693 (+/-0.099) for {'n_estimators': 460, 'max_depth': None}

# %%
cv_random.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=60)

# %%
joblib.dump(cv_random.best_estimator_, 'RS_model.pkl')
# Out:
# ['RS_model.pkl']

# %%
search_models = {}

for s_mdl in ['GS', 'RS']:
    search_models[s_mdl] = joblib.load('{}_model.pkl'.format(s_mdl))

# %%
search_models
# Out:
# {'GS': RandomForestClassifier(max_depth=3),
#  'RS': RandomForestClassifier(max_depth=10, n_estimators=60)}

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
from time import time

def evaluate_model(name, model, features, labels):
    start = time()
    pred = model.predict(features)
    end = time()
    accuracy = round(accuracy_score(labels, pred), 3)
    precision = round(precision_score(labels, pred, average='weighted'), 3)
    recall = round(recall_score(labels, pred, average='weighted'), 3)
    print('{} -- Accuracy: {} / Precision: {} / Recall: {} / Latency: {}ms'.format(name,
                                                                                   accuracy,
                                                                                   precision,
                                                                                   recall,
                                                                                   round((end - start)*1000, 1)))

# %%
for name, mdl in search_models.items():
    evaluate_model(name, mdl, x_feature, y_label)
# Out:
# GS -- Accuracy: 0.748 / Precision: 0.745 / Recall: 0.748 / Latency: 158.9ms
# RS -- Accuracy: 0.905 / Precision: 0.904 / Recall: 0.905 / Latency: 114.5ms

# %%
evaluate_model('Random Search', search_models['RS'], x_feature, y_label)
# Out:
# Random Search -- Accuracy: 0.905 / Precision: 0.904 / Recall: 0.905 / Latency: 75.6ms
